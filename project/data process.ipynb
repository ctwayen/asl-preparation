# %%
import pandas as pd

# %%
signs = pd.read_csv("data/asl_proj_signs.csv")

# %%
signs
# Out:
#           Sign Start Hand Type End Hand Type Start Position End Position  \
# 0         Nice              hb           hb           chest        chest
# 1         Meet            vone          vone          chest        chest
# 2        learn             hbb           hbb          chest         head
# 3        Teach             hbb           hbb          chest        chest
# 4       Sister              va            vl          cheek        chest
# 5          man              vb            vb           head        chest
# 6        woman              vb            vb          cheek        chest
# 7          boy              hb           hb            head         head
# 8         girl              va            va          cheak        cheak
# 9       father              vb            vb           head         head
# 10      mother              vb            vb           chin         chin
# 11     Brother              va            vl           head        chest
# ...

# %%
signs["Start Hand Type"].value_counts()
# Out:
# vb       10
# vone      7
# hone      7
# va        6
# vfive     6
# hb        4
# f         3
# hbb       3
# s         2
# hy        2
# hfive     2
# hl        1
# p         1
# vl        1
# hf        1
# hg        1
# vy        1
# vbb       1
# w         1
# Name: Start Hand Type, dtype: int64

# %%
signs["End Hand Type"].value_counts()
# Out:
# vb       8
# hone     7
# vone     5
# hbb      5
# s        4
# hy       4
# va       4
# vfive    4
# hb       3
# f        3
# hb       3
# vl       3
# hfive    2
# hg       1
# p        1
# hl       1
# hf       1
# w        1
# Name: End Hand Type, dtype: int64

# %%
shape_dct = {'vb': 'vertical b shape', 'hb': 'horizental b shape', 'vfive': 
             'vertical five shape', 'hfive': 'horizental five shape',
             'hone': 'horizental one shape', 'vone': 'vertical one shape',
             'p': 'p shape', 'f': 'f shape', 's': 's shape', 'hl': 'horizental l shape',
             'w': 'w shape', 'va': 'vertical a shape', 'hbb': 'horizental bent b shape',
             'hg': 'horizental g shape', 'hy': 'horizental y shape'
             }
pd.Series(shape_dct).to_frame()
# Out:
#                              0
# vb            vertical b shape
# hb          horizental b shape
# vfive      vertical five shape
# hfive    horizental five shape
# hone      horizental one shape
# vone        vertical one shape
# p                      p shape
# f                      f shape
# s                      s shape
# hl          horizental l shape
# w                      w shape
# va            vertical a shape
# hbb    horizental bent b shape
# hg          horizental g shape
# hy          horizental y shape

# %%
signs.loc[39, 'Movement Axis'] = 'r'

# %%
signs['Movement Axis'].value_counts()
# r means repeat, z means move along z axis, ro means rotation, ar means around
# Out:
# r     24
# z     15
# ro     7
# x      7
# y      6
# ar     1
# Name: Movement Axis, dtype: int64
